# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique)

# %%
from sklearn.datasets import make_classification

''' library to use SMOTE '''
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/harshit/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (3.5.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
X,y = make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1, weights=[0.90], random_state=12)

# %%
import pandas as pd

df1 = pd.DataFrame(X, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])
final_df = pd.concat([df1,df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X,y = oversample.fit_resample(final_df[['f1','f2']], final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Out:
# 900

# %%
df1 = pd.DataFrame(X, columns=['f1','f2'])
df2 = pd.DataFrame(y, columns=['target'])

oversample_df = pd.concat([df1,df2], axis=1)

# %%
plt.scatter(oversample_df['f1'], oversample_df['f2'], c=oversample_df['target'])
